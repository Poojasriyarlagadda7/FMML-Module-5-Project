# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojasriyarlagadda7/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 15:51:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   290MB/s    in 0.2s
#
# 2024-04-05 15:51:36 (290 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface
#
# ---

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14253   1311.2694v2  Community detection in networks is a key explo...  stat
# 21957   1007.0832v1  We define a class of Euclidean distances on we...  stat
# 22131  1501.04080v2  Bayesian optimization is a powerful tool for f...  stat
# 27394  1703.05243v2  Given the progress in image recognition with r...    cs
# 3611   1802.07129v1  In "extreme" computational imaging that collec...  stat
# ...             ...                                                ...   ...
# 14079  1708.06008v1  We review Boltzmann machines and energy-based ...    cs
# 40513   1208.3145v1  We investigate two classes of transformations ...  stat
# 35338  cs/0407021v2  Recently, Jadbabaie, Lin, and Morse (IEEE TAC,...    cs
# 37848   0811.2177v3  Assigning significance in high-dimensional reg...  stat
# 21579   1103.5202v2  In this paper, we give a new sharp generalizat...  stat
#
#                                                    title  year  \
# 14253  Hypothesis Testing for Automated Community Det...  2013
# 21957  Euclidean Distances, soft and spectral Cluster...  2010
# 22131       Differentially Private Bayesian Optimization  2015
# 27394  A Hybrid Supervised-unsupervised Method on Ima...  2017
# 3611   Deep BCD-Net Using Identical Encoding-Decoding...  2018
# ...                                                  ...   ...
# 14079         Boltzmann machines and energy-based models  2017
# 40513  Metric distances derived from cosine similarit...  2012
# 35338  Multi-agent coordination using nearest neighbo...  2004
# 37848           P-values for high-dimensional regression  2008
# 21579  Fast Learning Rate of lp-MKL and its Minimax O...  2011
#
#                                                 keywords
# 14253  [community, detection, exploratory, applicatio...
# 21957  [euclidean, distances, thermodynamic, clusteri...
# 22131  [optimization, parameters, practitioners, clas...
# 27394  [recognition, paradigms, expensive, convolutio...
# 3611   [computational, extremely, undersampled, measu...
# ...                                                  ...
# 14079  [boltzmann, boltzmann, probability, distributi...
# 40513  [investigate, transformations, similarity, cor...
# 35338  [jadbabaie, mathematical, autonomous, jadbabai...
# 37848  [assigning, significance, dimensional, regress...
# 21579  [generalization, generalized, framework, regul...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14253    [community, detection, exploratory, applicatio...
# 21957    [euclidean, distances, thermodynamic, clusteri...
# 22131    [optimization, parameters, practitioners, clas...
# 27394    [recognition, paradigms, expensive, convolutio...
# 3611     [computational, extremely, undersampled, measu...
#                                ...
# 30362    [visibility, applications, impossible, degradi...
# 21939    [prediction, algorithms, bootstrap, algorithm,...
# 19813    [currently, arguments, explaining, evaluating,...
# 10459    [statistical, minimization, confidential, fram...
# 22641    [clustering, partition, objective, clustering,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4534 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9110db04-6a08-4aa6-ad11-5c58cd35ad0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9110db04-6a08-4aa6-ad11-5c58cd35ad0e")) {                    Plotly.newPlot(                        "9110db04-6a08-4aa6-ad11-5c58cd35ad0e",                        [{"x":["adjacency","clustering","generated","eigenvalue","community","biological","determine","theoretically","outperforms","exploratory","identifying","distribution","hypothesis","establish","communities","unlabeled","algorithms","knowledge","automatically","blockmodel","quantifiable","statistics","overlapping","probabilistic","classification","attention","recursive","detection","algorithm","automated","contribution","applications","principal","stochastic","structure","thermodynamic","visualization","conditioned","distances","embeddings","euclidean","illustrate","encountered","geographical","coordinates","procedure","constructed","dimensional","commonplace","privately","different","satisfied","differentially","smoothness","parameters","leveraging","introduce","assumption","guarantees","classifier","differential","sensitive","parameter","releasing","convergence","observation","practitioners","classifiers","theoretical","optimization","attractive","quantities","practical","supervised","experiments","unsupervised","combining","convolutional","consistent","assignments","visualize","parallelization","performance","categories","representations","detecting","recognition","allocation","dirichlet","scalability","expensive","egocentric","quantitatively","paradigms","comparing","conducted","computing","computational","reasonable","denoising","incorporating","incorporates","coordinate","iterative","measurements","undersampled","challenging","resonance","multipliers","structures","identical","conventional","moderately","numerical","variation","obtaining","extremely","alternating","potential","direction","reduction","inference","influence","previously","efficiently","evaluation","interesting","dimensionality","structured","reference","activation","regularization","variables","prediction","variability","agglomeration","constrained","meaningful","techniques","predictive","representation","multivariate","information","populations","univariate","specifically","precisely","penalization","currently","spatially","agglomerative","analyzing","simultaneously","cognitive","selection","hierarchical","statistical","delineates","functional","predicting","acceleration","satisfactory","lipschitz","methodology","presented","financial","framework","stationary","properties","continuous","unsatisfactory","contractive","converges","procedures","iteration","distributed","equilibria","geometrical","improvement","contraction","rightarrow","integration","relationship","highlight","uniformly","arbitrary","characteristic","dimensions","approximation","normalized","increasingly","approximated","transformation","sufficiently","estimation","objective","prototypical","furthermore","effective","maintains"],"y":[7,141,178,2,60,35,65,32,244,4,69,195,67,44,19,43,610,347,185,1,3,60,21,180,510,168,16,344,825,103,71,457,33,131,349,1,25,15,34,73,38,71,20,4,10,115,70,170,2,1,790,10,7,15,251,34,359,65,67,136,29,47,116,1,124,50,16,120,166,323,22,9,133,208,602,139,119,390,84,16,15,8,883,81,238,79,367,24,22,31,72,10,29,14,77,82,119,287,42,43,60,36,24,78,50,3,285,25,7,141,15,99,0,81,60,45,47,24,157,50,104,202,45,105,163,260,61,52,103,63,35,85,116,213,31,1,62,42,364,46,364,16,683,13,7,165,21,1,65,22,3,61,98,39,139,118,168,2,38,73,13,22,6,64,163,12,567,31,217,93,4,1,22,42,42,121,8,14,145,3,3,45,67,27,19,79,19,48,108,28,42,19,62,23,190,161,7,166,234,6],"type":"bar"},{"x":["adjacency","clustering","generated","eigenvalue","community"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4534,), (4534, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Collaborative</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Collaborative</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>Given</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3607476635514019);'>representation</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>unified</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporates</span> <span style=''>the</span> <span style=''>features</span> <span style=''>from</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4393939393939393);'>discriminative</span> <span style=''>power</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3607476635514019);'>representation</span> <span style=''>matrix</span> <span style=''>on</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>separately</span> <span style='background-color:rgba(0, 255, 0, 0.37728937728937717);'>Experimental</span> <span style='background-color:rgba(0, 255, 0, 0.4325068870523415);'>evaluation</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>on</span> <span style=''>separate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>and</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborative</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Double</span> <span style=''>Coupled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Canonical</span> <span style=''>Polyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>for</span> <span style=''>Joint</span> <span style=''>Blind</span> <span style=''>Source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separation</span> <br/><br/><span style=''>Joint</span> <span style=''>blind</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>(J</span> <span style=''>BSS)</span> <span style=''>is</span> <span style=''>an</span> <span style=''>emerging</span> <span style=''>data</span> <span style=''>driven</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>set</span> <span style=''>data</span> <span style=''>fusion</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>J</span> <span style=''>BSS</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tensorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>by</span> <span style=''>using</span> <span style=''>second</span> <span style=''>order</span> <span style=''>multi</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>in</span> <span style=''>J</span> <span style=''>BSS</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>double</span> <span style=''>coupled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style=''>polyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>(DC</span> <span style=''>CPD)</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style=''>DC</span> <span style=''>CPD</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>coupled</span> <span style=''>rank</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>mapping</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>converts</span> <span style=''>a</span> <span style=''>possibly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underdetermined</span> <span style=''>DC</span> <span style=''>CPD</span> <span style=''>to</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overdetermined</span> <span style=''>CPDs</span> <span style=''>The</span> <span style=''>latter</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>algebraically</span> <span style=''>via</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalue</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>based</span> <span style=''>scheme</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Restricted</span> <span style=''>Causal</span> <span style='background-color:rgba(255, 0, 0, 0.32100840336134456);'>Inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>belief</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>data</span> <span style=''>handling</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.4096692111959288);'>variables</span> <span style=''>It</span> <span style=''>consists</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CI</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>of</span> <span style=''>Spirtes</span> <span style=''>et</span> <span style=''>al</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricting</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>checked</span> <span style=''>up</span> <span style=''>to</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.4096692111959288);'>variables</span> <span style=''>and</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>CI</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>steps</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforming</span> <span style=''>so</span> <span style=''>called</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>path</span> <span style=''>graph</span> <span style=''>into</span> <span style=''>a</span> <span style=''>belief</span> <span style=''>network</span> <span style=''>Its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctness</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Strategies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressed</span> <span style=''>Fiber</span> <span style=''>Sensing</span> <span style=''>Using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>Sparse</span> <span style=''>Model</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>fiber</span> <span style=''>sensing</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>sparse</span> <span style=''>model</span> <span style=''>To</span> <span style=''>handle</span> <span style=''>severe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shrinkage</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Weibull</span> <span style=''>prior</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>related</span> <span style=''>to</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>p</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>for</span> <span style=''>0</span> <span style=''>p</span> <span style=''>1</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>leverage</span> <span style=''>the</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>to</span> <span style=''>promote</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shrinkage</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>model</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporated</span> <span style=''>in</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>in</span> <span style=''>the</span> <span style=''>joint</span> <span style=''>prior</span> <span style=''>density</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>thereby</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishing</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>relation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style='background- ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12339971550497866)
# 	experimental (0.1337126600284495)
# 	architecture (0.08499288762446658)
# 	challenging (0.10135135135135136)
# 	information (0.24288762446657183)
# 	segmentation (0.07503556187766713)
# 	detection (0.12233285917496443)
# 	different (0.2809388335704125)
# 	recognition (0.13051209103840683)
# 	convolutional (0.1386913229018492)
#
# Some Statistics words are:
# 	statistical (0.14738430583501005)
# 	stochastic (0.13430583501006035)
# 	algorithm (0.3908450704225352)
# 	variables (0.13933601609657947)
# 	theoretical (0.158953722334004)
# 	estimation (0.17354124748490946)
# 	distribution (0.1805835010060362)
# 	dimensional (0.17756539235412475)
# 	inference (0.1976861167002012)
# 	regression (0.18611670020120724)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c17218b1-b2dc-4c66-92c9-9afb9ae86c88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c17218b1-b2dc-4c66-92c9-9afb9ae86c88")) {                    Plotly.newPlot(                        "c17218b1-b2dc-4c66-92c9-9afb9ae86c88",                        [{"x":["adjacency","clustering","generated","eigenvalue","community","biological","determine","theoretically","outperforms","exploratory","identifying","distribution","hypothesis","establish","communities","unlabeled","algorithms","knowledge","automatically","blockmodel","quantifiable","statistics","overlapping","probabilistic","classification","attention","recursive","detection","algorithm","automated","contribution","applications","principal","stochastic","structure","thermodynamic","visualization","conditioned","distances","embeddings","euclidean","illustrate","encountered","geographical","coordinates","procedure","constructed","dimensional","commonplace","privately","different","satisfied","differentially","smoothness","parameters","leveraging","introduce","assumption","guarantees","classifier","differential","sensitive","parameter","releasing","convergence","observation","practitioners","classifiers","theoretical","optimization","attractive","quantities","practical","supervised","experiments","unsupervised","combining","convolutional","consistent","assignments","visualize","parallelization","performance","categories","representations","detecting","recognition","allocation","dirichlet","scalability","expensive","egocentric","quantitatively","paradigms","comparing","conducted","computing","computational","reasonable","denoising","incorporating","incorporates","coordinate","iterative","measurements","undersampled","challenging","resonance","multipliers","structures","identical","conventional","moderately","numerical","variation","obtaining","extremely","alternating","potential","direction","reduction","inference","influence","previously","efficiently","evaluation","interesting","dimensionality","structured","reference","activation","regularization","variables","prediction","variability","agglomeration","constrained","meaningful","techniques","predictive","representation","multivariate","information","populations","univariate","specifically","precisely","penalization","currently","spatially","agglomerative","analyzing","simultaneously","cognitive","selection","hierarchical","statistical","delineates","functional","predicting","acceleration","satisfactory","lipschitz","methodology","presented","financial","framework","stationary","properties","continuous","unsatisfactory","contractive","converges","procedures","iteration","distributed","equilibria","geometrical","improvement","contraction","rightarrow","integration","relationship","highlight","uniformly","arbitrary","characteristic","dimensions","approximation","normalized","increasingly","approximated","transformation","sufficiently","estimation","objective","prototypical","furthermore","effective","maintains","associate","demonstrate","questionnaires","questions","submodular","published","presumably","extension","interpretable","symmetric","providing","criticisms","indicative","importance","submodularity","selecting","addressing","available","prototypes","requirement","scientific","additional","prototype","maintained","efficient","generalizes","qualitatively","factorization","efficiency","gracefully","dimension","significant","randomized","dictionary","complexity","applicability","processed","addressed","recommender","decompositions","completion","viewpoints","similarity","surprisingly","encouraged","advantages","similarities","estimating","particular","averaging","fundamental","operation","integrated","generative","develo ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	moderately
# 	criticisms
# 	repulsion
# 	semiparametric
# 	parametrizations
# 	econometrics
# 	geodesics
# 	incidentally
# 	analogues
# 	electroencephalography
# 	nonconjugate
# 	breaching
# 	initialise
# 	recidivism
# 	misspecified
# 	heteroscedastic
# 	worsening
# 	subgaussian
# 	lucrative
# 	epidemics
# Some words which never appear in Statistics papers:
# 	equilibria
# 	extractive
# 	understandable
# 	evaluator
# 	acquisitions
# 	disability
# 	compatibility
# 	specialization
# 	obstacles
# 	biomedicine
# 	precondition
# 	comprehend
# 	illumination
# 	insertion
# 	discourse
# 	exacerbated
# 	enforcement
# 	unidentified
# 	propositions
# 	plausibility

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac
#
# 1.   List item
# 2.   List item
#
# {\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0624119556562746e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
